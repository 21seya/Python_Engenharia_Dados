# %%
import matplotlib.pyplot as plt 
import numpy as np 

x = np.array([1,2,3,4,5])
y = np.array([2,3,4,5,6])

plt.plot(x,y)
plt.show()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.9.2' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt
import numpy as np 

x = np.array([0,1,2,3,4,5])
y = x * 2 

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

x = np.array([0,1,2,3,4,5])
y = np.array(["Segunda","Terça","Quarta","Quinta","Sexta","Sabado"])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

x1 = np.array([1,2,3,4,5])
y1 = x1 * 2 

x2 = np.array([5,10,15])
y2 = x2 * 2

plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 

x1 = np.arange(1,10)
y1 = x1 * 2 

x2 =np.arange(1,10)
y2 = x2 ** 2 

plt.plot(x1,y2)
#plt.axis(0,80)
plt.show()
